# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" +"tv"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipcart_url)

# %%
flipcart_page = urlclient.read()

# %%
# flipcart_page

# %%
flipcart_html = bs(flipcart_page , 'html.parser')

# %%
flipcart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com"+"//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"
# Out:
# 'https://www.flipkart.com//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css'

# %%
bigbox = flipcart_html.find_all("div" ,{"class":"_1AtVbE col-12-12"} )

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com" + bigbox[0].div.div.div.a['href']

# %%
for i in bigbox:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/compaq-140-cm-55-inch-ultra-hd-4k-led-smart-android-tv/p/itmde1e14acf6493?pid=TVSGHQYFM4EVQPYU&lid=LSTTVSGHQYFM4EVQPYUS1YEBQ&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_QN%2FAqk4XU2XvvyaToXr%2BNuSCmFWuLBgtRlm6c809z%2FPaXX0VIZNKsZ5s4XLwJsp%2FUiv1ykRvAl1n4pn0Pm4%2Feg%3D%3D&ppt=None&ppn=None&ssid=9ldhv1ah340000001682361449918&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/lg-80-cm-32-inch-hd-ready-led-smart-webos-tv/p/itm6207e6d122567?pid=TVSFTW4CSRW8PGDQ&lid=LSTTVSFTW4CSRW8PGDQSZQIO6&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=FkPickId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=ef893c2f-e4f4-41c3-8751-f03b75860722.TVSFTW4CSRW8PGDQ.SEARCH&ppt=None&ppn=None&ssid=9ldhv1ah340000001682361449918&qH=c9a1fdac6e082dd8
# ...

# %%
productlink
# Out:
# 'https://www.flipkart.com/compaq-140-cm-55-inch-ultra-hd-4k-led-smart-android-tv/p/itmde1e14acf6493?pid=TVSGHQYFM4EVQPYU&lid=LSTTVSGHQYFM4EVQPYUS1YEBQ&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_QN%2FAqk4XU2XvvyaToXr%2BNuSCmFWuLBgtRlm6c809z%2FPaXX0VIZNKsZ5s4XLwJsp%2FUiv1ykRvAl1n4pn0Pm4%2Feg%3D%3D&ppt=None&ppn=None&ssid=9ldhv1ah340000001682361449918&qH=c9a1fdac6e082dd8'

# %%
procuct_req = requests.get(productlink)

# %%
product_html = bs(procuct_req.text,'html.parser')

# %%
coment_box = product_html.find_all("div",{"class":"_16PBlm"})

# %%
len(coment_box)
# Out:
# 11

# %%
coment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'KHUSRO KHAN'

# %%
for i in coment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# KHUSRO KHAN
# Abhishek  Kumar
# Flipkart Customer
# Ruben Gomez
# Rakesh Bhai
# shaik imran
# Raghuveer M
# Kartik prakash
# CHANDRA BHANU REDDY
# Flipkart Customer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 for i in coment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in coment_box:
    print(i.div.div.div.div.text)
# Out:
# 4
# 5
# 5
# 2
# 4
# 4
# 4
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 for i in coment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
coment_box[0].div.div.div.p.text
# Out:
# 'Good TV Adding Missing Points for Better Review'

# %%
for i in coment_box:
    print(i.div.div.div.p.text )
# Out:
# Good TV Adding Missing Points for Better Review
# Awesome
# Fabulous!
# Not good
# Good choice
# Worth the money
# Value Product
# Does not come with proper wall mount
# Wonderful
# Mind-blowing purchase
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 for i in coment_box:
# ----> 2     print(i.div.div.div.p.text )
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
coment_box[0].div.div.find_all("div",{"class":""})[0].text
# Out:
# "Initial Review of TV and Adding Missing Points in the Product DescriptionProns-Dual Band WifiAlmost Beezeless TV from 3 sidesThe sound is Good ( Don't Expect Bass or sound like a music system just good normal sound with minor bass sometimes)Enough Ports for good connectivitySmart Remote and Smooth UI PerformanceCons-Brightness is low but not too low I feel it's lower than my old 32-inch LEDTV clarity is not excellent but yes very good.The startup is a bit slow but it's manageabl...READ MORE"

# %%
for i in coment_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# Initial Review of TV and Adding Missing Points in the Product DescriptionProns-Dual Band WifiAlmost Beezeless TV from 3 sidesThe sound is Good ( Don't Expect Bass or sound like a music system just good normal sound with minor bass sometimes)Enough Ports for good connectivitySmart Remote and Smooth UI PerformanceCons-Brightness is low but not too low I feel it's lower than my old 32-inch LEDTV clarity is not excellent but yes very good.The startup is a bit slow but it's manageabl...READ MORE
# Extremely value for money product sound quality is superb for a hall or living room and support all app very smoothly remote was easy to use and i think comapaq is a trustable brand of hp so go for it also you will get an extra wall hanging kit without extra chargeREAD MORE
# ...
